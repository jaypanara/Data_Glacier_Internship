# %% [markdown]
# # **G2M insight for Cab Investment firm**

# %% [markdown]
# Importing the required libraries:

# %%
import pandas as pd

# %% [markdown]
# Reading the .csv files:

# %%
Cab_Data = pd.read_csv("./drive/MyDrive/G2M_Cab_Investment/Cab_Data.csv")
City = pd.read_csv("./drive/MyDrive/G2M_Cab_Investment/City.csv")
Customer_ID = pd.read_csv("./drive/MyDrive/G2M_Cab_Investment/Customer_ID.csv")
Transaction_ID = pd.read_csv("./drive/MyDrive/G2M_Cab_Investment/Transaction_ID.csv")

# %% [markdown]
# ### Exploring each file:

# %% [markdown]
# ##**Cab_Data**

# %%
Cab_Data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %% [markdown]
# From the above table we observe that the date of travel is not in the correct format. Hence, changing it to the right format of YYYY-MM-DD.

# %%
from datetime import datetime, date, timedelta

Cab_Data["Date of Travel"] = Cab_Data["Date of Travel"].apply(lambda x: date(1899, 12,30) + timedelta(x))
# display
Cab_Data.head(5)
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
Cab_Data.shape
# Out:
# (359392, 7)

# %% [markdown]
# There are 359392 rows and 7 columns

# %%
Cab_Data.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip'],
#       dtype='object')

# %%
Cab_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  object
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 19.2+ MB

# %% [markdown]
# There are no missing values in the data.

# %%
Cab_Data.describe().round(2)
# Out:
#        Transaction ID  KM Travelled  Price Charged  Cost of Trip
# count       359392.00     359392.00      359392.00     359392.00
# mean      10220761.19         22.57         423.44        286.19
# std         126805.80         12.23         274.38        157.99
# min       10000011.00          1.90          15.60         19.00
# 25%       10110809.75         12.00         206.44        151.20
# 50%       10221035.50         22.44         386.36        282.48
# 75%       10330937.25         32.96         583.66        413.68
# max       10440107.00         48.00        2048.03        691.20

# %% [markdown]
# ## **City:**

# %%
City
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
City.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
City.shape
# Out:
# (20, 3)

# %% [markdown]
# It consists of 20 rows and 3 columns.

# %%
City.columns
# Out:
# Index(['City', 'Population', 'Users'], dtype='object')

# %%
City.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %% [markdown]
# There are no null values in the data.

# %%
City.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %% [markdown]
# ##**Customer_ID:**

# %%
Customer_ID.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
Customer_ID.shape
# Out:
# (49171, 4)

# %% [markdown]
# There are 49171 rows and 4 columns.

# %%
Customer_ID.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Income (USD/Month)'], dtype='object')

# %%
Customer_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# There are no null values in the data.

# %%
Customer_ID.describe().round(2)
# Out:
#        Customer ID       Age  Income (USD/Month)
# count     49171.00  49171.00            49171.00
# mean      28398.25     35.36            15015.63
# std       17714.14     12.60             8002.21
# min           1.00     18.00             2000.00
# 25%       12654.50     25.00             8289.50
# 50%       27631.00     33.00            14656.00
# 75%       43284.50     42.00            21035.00
# max       60000.00     65.00            35000.00

# %% [markdown]
# ## **Transaction_ID:**

# %%
Transaction_ID.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
Transaction_ID.shape
# Out:
# (440098, 3)

# %% [markdown]
# There are 440098 rows and 3 columns.

# %%
Transaction_ID.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Payment_Mode'], dtype='object')

# %%
Transaction_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %% [markdown]
# There are no null values in the data.

# %%
Transaction_ID.describe().round(2)
# Out:
#        Transaction ID  Customer ID
# count       440098.00    440098.00
# mean      10220059.50     23619.51
# std         127045.49     21195.55
# min       10000011.00         1.00
# 25%       10110035.25      3530.00
# 50%       10220059.50     15168.00
# 75%       10330083.75     43884.00
# max       10440108.00     60000.00

# %% [markdown]
# ## **Merging Transaction_ID and Customer_ID**

# %%
new_Customer_ID = Customer_ID.merge(Transaction_ID, on = 'Customer ID')
new_Customer_ID.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Income (USD/Month)', 'Transaction ID',
#        'Payment_Mode'],
#       dtype='object')

# %%
new_Customer_ID.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card

# %% [markdown]
# ## **Merging new Customer_ID with Cab_Data**

# %%
new_Cab_Data = Cab_Data.merge(new_Customer_ID, on = ['Transaction ID'])
new_Cab_Data.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Customer ID', 'Gender', 'Age',
#        'Income (USD/Month)', 'Payment_Mode'],
#       dtype='object')

# %%
new_Cab_Data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Gender  Age  Income (USD/Month)  \
# 0         370.95       313.635        29290   Male   28               10813
# 1         358.52       334.854        27703   Male   27                9237
# 2         125.20        97.632        28712   Male   53               11242
# 3         377.40       351.602        28020   Male   23               23327
# 4         114.62        97.776        27182   Male   33                8536
#
#   Payment_Mode
# 0         Card
# 1         Card
# 2         Cash
# 3         Cash
# ...

# %%
new_Cab_Data.tail()
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 359387          4.80          69.24       63.3600        52392   Male   24
# 359388          8.40         113.75      106.8480        53286   Male   32
# 359389         27.75         437.07      349.6500        52265   Male   56
# 359390          8.80         146.19      114.0480        52175   Male   32
# 359391         12.76         191.58      177.6192        52917   Male   20
#
#         Income (USD/Month) Payment_Mode
# 359387               15651         Cash
# 359388                6528         Cash
# ...

# %% [markdown]
# ## **Merging new_Cab_Data with City**

# %%
new_Cab_Data = new_Cab_Data.merge(City, on = 'City')
new_Cab_Data.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Customer ID', 'Gender', 'Age',
#        'Income (USD/Month)', 'Payment_Mode', 'Population', 'Users'],
#       dtype='object')

# %%
new_Cab_Data['Population'] = [x.replace(',','') for x in new_Cab_Data['Population']]
new_Cab_Data['Population'] = new_Cab_Data['Population'].astype(int)

new_Cab_Data['Users'] = [x.replace(',','') for x in new_Cab_Data['Users']]
new_Cab_Data['Users'] = new_Cab_Data['Users'].astype(int)

new_Cab_Data['Users'] = new_Cab_Data['Users'].astype(str).astype(int)

# %%
new_Cab_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  object
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Gender              359392 non-null  object
#  9   Age                 359392 non-null  int64
#  10  Income (USD/Month)  359392 non-null  int64
#  11  Payment_Mode        359392 non-null  object
#  12  Population          359392 non-null  int64
#  13  Users               359392 non-null  int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 41.1+ MB

# %%
new_Cab_Data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Gender  Age  Income (USD/Month)  \
# 0         370.95       313.635        29290   Male   28               10813
# 1         358.52       334.854        27703   Male   27                9237
# 2         125.20        97.632        28712   Male   53               11242
# 3         377.40       351.602        28020   Male   23               23327
# 4         114.62        97.776        27182   Male   33                8536
#
#   Payment_Mode  Population  Users
# 0         Card      814885  24701
# ...

# %% [markdown]
# Checking the various cab companies in the city:

# %%
new_Cab_Data.Company.unique()
# Out:
# array(['Pink Cab', 'Yellow Cab'], dtype=object)

# %% [markdown]
# ## **Checking for duplicates in the dataframe:**

# %%
new_Cab_Data.duplicated().sum()
# Out:
# 0

# %%
new_Cab_Data.loc[new_Cab_Data.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date of Travel, Company, City, KM Travelled, Price Charged, Cost of Trip, Customer ID, Gender, Age, Income (USD/Month), Payment_Mode, Population, Users]
# Index: []

# %% [markdown]
# It is oberseved that there are no duplicates in the new merged dataframe.

# %% [markdown]
# ## **Analysis of the Dataframe**

# %% [markdown]
# Plotting the number of pink and yellow cabs running in the city:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(font_scale=1.4)
new_Cab_Data['Company'].value_counts().plot(kind='bar', figsize=(7, 6), rot=0);
plt.xlabel("Company", labelpad=14)
plt.ylabel("Number of Cabs", labelpad=14)
plt.title("Number of cabs of a particular company running in the cities", y=1.02);

# %% [markdown]
# It is observed that there are more cabs of Yellow cab company running around the cities.

# %%
plt.figure(figsize=(10, 10));
Users_City=sns.barplot(x='Users', y='City', data=new_Cab_Data);

# %% [markdown]
# It is observed that the highest number of users are from New York.

# %%
pink_cab = new_Cab_Data[new_Cab_Data.Company.isin(["Pink Cab"])]
pink_cab.head()
yellow_cab = new_Cab_Data[new_Cab_Data.Company.isin(["Yellow Cab"])]
yellow_cab.head()
# Out:
#     Transaction ID Date of Travel     Company        City  KM Travelled  \
# 6         10000384     2016-01-02  Yellow Cab  ATLANTA GA         33.93
# 7         10000385     2016-01-09  Yellow Cab  ATLANTA GA         42.18
# 8         10000386     2016-01-03  Yellow Cab  ATLANTA GA         10.60
# 9         10000387     2016-01-06  Yellow Cab  ATLANTA GA         26.75
# 10        10000388     2016-01-07  Yellow Cab  ATLANTA GA         46.02
#
#     Price Charged  Cost of Trip  Customer ID Gender  Age  Income (USD/Month)  \
# 6         1341.17      464.1624        27602   Male   23                8542
# 7         1412.06      516.2832        27594   Male   28                3901
# 8          364.62      132.2880        27884   Male   32               13505
# 9          838.00      333.8400        28533   Male   39               28386
# 10        1540.61      596.4192        29039   Male   35               17761
#
#    Payment_Mode  Population  Users    Profit  Year of Travel
# ...

# %%
pink_transaction = pink_cab.groupby("Year of Travel")['Transaction ID'].count()
yellow_transaction = yellow_cab.groupby("Year of Travel")['Transaction ID'].count()

labels=['2016','2017','2018']
plt.figure(figsize=(17,9))
ax1 = plt.subplot(111)
ax1.bar(labels, pink_transaction.values, width=0.4, color='pink', align='center',label='Pink Cab')
ax1.bar(labels, yellow_transaction.values, width=0.4, color='yellow', align='center',label='Yellow Cab',bottom=pink_transaction)
plt.title("Pink cab vs Yellow cab",fontsize = 20)
plt.ylabel('No. of Transactions',fontsize = 15)
plt.xlabel('Year',fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# It is observed that there are more transaction done for the yellow cab than the pink cabs in three years span.

# %% [markdown]
# Let's observe the distribution of various age groups:

# %%
plt.figure(figsize=(15,15))
sns.set(style="darkgrid")
sns.histplot(data=new_Cab_Data, x="Age")
plt.show()

# %% [markdown]
# It is observed that the age groups above 40 do not use the cab services much.

# %% [markdown]
# Let's check the relation between price charged and the distance travelled by the two cab companies.

# %%
sns.relplot(
    data=new_Cab_Data, kind="line",
    x="KM Travelled", y="Price Charged", hue="Company",
)

# %% [markdown]
# It is observed that the prices of the yellow cab are higher for each distance travelled when compared to the pink cab.

# %% [markdown]
# Let's observe the profit which the companies received from the trips and for that we need to create another column of profits.

# %%
new_Cab_Data['Profit'] = new_Cab_Data['Price Charged'] - new_Cab_Data['Cost of Trip']

# %%
new_Cab_Data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Gender  Age  Income (USD/Month)  \
# 0         370.95       313.635        29290   Male   28               10813
# 1         358.52       334.854        27703   Male   27                9237
# 2         125.20        97.632        28712   Male   53               11242
# 3         377.40       351.602        28020   Male   23               23327
# 4         114.62        97.776        27182   Male   33                8536
#
#   Payment_Mode  Population  Users  Profit
# 0         Card      814885  24701  57.315
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.title("Company wise profit")
profit_pie = new_Cab_Data.groupby('Company')['Profit'].sum()
colour = ['pink', 'yellow']
profit_pie.plot(kind='pie',y='Company',startangle=0,figsize=(15,12),autopct='%1.5f%%',explode=[0.03]*2, colors = colour)

# %% [markdown]
# It is observed that the profit share of yellow cab is more than the pink cab.

# %% [markdown]
# Adding another column for the year of travel.

# %%
new_Cab_Data['Year of Travel']=pd.DatetimeIndex(new_Cab_Data['Date of Travel']).year
new_Cab_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  object
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Gender              359392 non-null  object
#  9   Age                 359392 non-null  int64
#  10  Income (USD/Month)  359392 non-null  int64
#  11  Payment_Mode        359392 non-null  object
#  12  Population          359392 non-null  int64
#  13  Users               359392 non-null  int64
#  14  Profit              359392 non-null  float64
# ...

# %% [markdown]
# Let's observe the yearly profit for botht the companies:

# %%
plt.figure(figsize=(10,10))
sns.pointplot(data=new_Cab_Data, x=new_Cab_Data["Year of Travel"], y=new_Cab_Data["Profit"], hue='Company')
plt.title('Yearly Profit',fontsize = 20)
plt.ylabel("Profit",fontsize = 16)
plt.xlabel("Year",fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# It is seen from the graph that the yearly profit dropped from 2017 to 2018.

# %% [markdown]
# Let's observe if there is any relation between distance travelled and the profit.

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=new_Cab_Data, x='KM Travelled', y='Profit', hue='Company')
plt.title('KM Travelled vs Profit',fontsize = 20)
plt.ylabel('Profit',fontsize = 16)
plt.xlabel('KM Travelled',fontsize = 16)
plt.show()

# %% [markdown]
# It is seen that more profit is earned as the KMs increases for both the companies but the profit earned by Yellow cabs is more compared to the pink cabs.

# %% [markdown]
# Lets observe the realtion between all the features in the dataframe:

# %%
sns.pairplot(new_Cab_Data)

# %% [markdown]
# Let's observe if there are any outliers for any feature:

# %%
fig,axes = plt.subplots(3,2 , figsize=(18, 18))
fig.suptitle('Boxplot graph')
sns.boxplot(ax=axes[0,0], x='KM Travelled', data=new_Cab_Data, y="Company", hue="Company", dodge=False)
sns.boxplot(ax=axes[0,1], x='Price Charged', data=new_Cab_Data, y="Company", hue="Company", dodge=False) 
sns.boxplot(ax=axes[1,0], x='Cost of Trip', data=new_Cab_Data, y="Company", hue="Company", dodge=False)
sns.boxplot(ax=axes[1,1], x='Income (USD/Month)', data=new_Cab_Data, y="Company", hue="Company", dodge=False)
sns.boxplot(ax=axes[2,0], x='Profit', data=new_Cab_Data, y="Company", hue="Company", dodge=False)
sns.boxplot(ax=axes[2,1], x='Age', data=new_Cab_Data, y="Company", hue="Company", dodge=False)

# %% [markdown]
# It is obeserved that there are outliers present in prices charged by the companies and the profits each company received from the trips.

# %% [markdown]
# Observations:
#
#
# *   It is observed that that are more yellow cabs running in the cities.
# *   New York city has the highest number of cab users.
# *   There are more transactions occuring for the yellow cab company compared to the pink cab company.
# *   Age groups below 40 prefer cabs than the ones above the age of 40.
# *   More prices are charged by the yellow company for the KMs travelled than its counterpart.
# *   The profit percent share of the yellow cab is almost 90% and that of the pink is 10%.
# *    There is a dip in the profit margins for both the companies.
# *    It is observed that more the distance travelled more is the profit for the companies.
# *    There are outliers present in the dataset for prices charged and the profit.
